# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import style
style.use('ggplot')

# %%
df = pd.read_csv('nba.games.stats.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Team  Game        Date  Home Opponent WINorLOSS  TeamPoints  \
# 0           1  ATL     1  2014-10-29  Away      TOR         L         102
# 1           2  ATL     2  2014-11-01  Home      IND         W         102
# 2           3  ATL     3  2014-11-05  Away      SAS         L          92
# 3           4  ATL     4  2014-11-07  Away      CHO         L         119
# 4           5  ATL     5  2014-11-08  Home      NYK         W         103
#
#    OpponentPoints  FieldGoals       ...        Opp.FreeThrows  \
# 0             109          40       ...                    27
# 1              92          35       ...                    18
# 2              94          38       ...                    27
# 3             122          43       ...                    20
# 4              96          33       ...                     8
#
#    Opp.FreeThrowsAttempted  Opp.FreeThrows.  Opp.OffRebounds  \
# 0                       33            0.818               16
# ...

# %%
df.fillna(-9999)
# Out:
#       Unnamed: 0 Team  Game        Date  Home Opponent WINorLOSS  TeamPoints  \
# 0              1  ATL     1  2014-10-29  Away      TOR         L         102
# 1              2  ATL     2  2014-11-01  Home      IND         W         102
# 2              3  ATL     3  2014-11-05  Away      SAS         L          92
# 3              4  ATL     4  2014-11-07  Away      CHO         L         119
# 4              5  ATL     5  2014-11-08  Home      NYK         W         103
# 5              6  ATL     6  2014-11-10  Away      NYK         W          91
# 6              7  ATL     7  2014-11-12  Home      UTA         W         100
# 7              8  ATL     8  2014-11-14  Home      MIA         W         114
# 8              9  ATL     9  2014-11-15  Away      CLE         L          94
# 9             10  ATL    10  2014-11-18  Home      LAL         L         109
# 10            11  ATL    11  2014-11-21  Home      DET         W          99
# ...

# %%
df.describe()
# Out:
#          Unnamed: 0         Game   TeamPoints  OpponentPoints   FieldGoals  \
# count   9840.000000  9840.000000  9840.000000     9840.000000  9840.000000
# mean   11960.157012    41.500000   103.652337      103.652337    38.602439
# std    18654.867508    23.670804    12.188043       12.188043     5.029992
# min        1.000000     1.000000    64.000000       64.000000    19.000000
# 25%     2537.750000    21.000000    95.000000       95.000000    35.000000
# 50%     5141.500000    41.500000   103.000000      103.000000    38.000000
# 75%     7715.250000    62.000000   112.000000      112.000000    42.000000
# max    82119.000000    82.000000   149.000000      149.000000    58.000000
#
#        FieldGoalsAttempted  FieldGoals.  X3PointShots  X3PointShotsAttempted  \
# count          9840.000000  9840.000000   9840.000000            9840.000000
# mean             84.902439     0.455689      9.126829              25.623679
# ...

# %%
LeagueTeamPoints = sum(df['TeamPoints'])

# %%
TotalGames = len(df['Game'])

# %%
LeagueTeamPointAverage = LeagueTeamPoints/TotalGames

# %%
print(LeagueTeamPointAverage)
# Out:
# 103.65233739837399

# %%
Home = np.array(df['Home'])
TeamPts = np.array(df['TeamPoints'])
print(Home)
# Out:
# ['Away' 'Home' 'Away' ... 'Home' 'Home' 'Away']

# %%
Home = Home.reshape(-1,1)
print(Home)
# Out:
# [['Away']
#  ['Home']
#  ['Away']
#  ...
#  ['Home']
#  ['Home']
#  ['Away']]

# %%
TeamPts = TeamPts.reshape(-1,1)

# %%
_ = np.hstack([Home,TeamPts])

# %%
print(_)
# Out:
# [['Away' 102]
#  ['Home' 102]
#  ['Away' 92]
#  ...
#  ['Home' 97]
#  ['Home' 113]
#  ['Away' 92]]

# %%
J = _[:1]
print(J)
# Out:
# [['Away' 102]]

# %%
HomePts = 0
AwayPts = 0
home = _[1][0]
away = _[0][0]
a = 0
 
for i in _:
    print(i[0][a])
    a=a+1
# Out:
# A
# o
# a
# y
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-74-722ba8e1f822> in <module>
#       6
#       7 for i in _:
# ----> 8     print(i[0][a])
#       9     a=a+1
#      10
#
# IndexError: string index out of range

# %%
print(HomePts)
# Out:
# 0
